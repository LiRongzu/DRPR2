# %%
import torch
import matplotlib.pyplot as plt
model_path = '/home/lirz6/PROGRAM/DRPR/outputs/2025-04-07/10-20-32_pipeline_new/models/som/som_model_salinity.pt' # 使用日志中的实际路径
try:
    loaded_data = torch.load(model_path, map_location='cpu')
    if isinstance(loaded_data, dict):
        print("Saved model keys:", loaded_data.keys())
        print("Saved model type:", loaded_data['feature_name'])
    else:
        print("Loaded data is not a dictionary:", type(loaded_data))
except Exception as e:
    print(f"Error loading model file: {e}")
# Out:
# Saved model keys: dict_keys(['weights', 'map_size', 'input_dim', 'sigma', 'lr', 'n_iterations', 'random_seed', 'qerrors', 'training_time', 'reconstruction_error', 'feature_name'])
# Saved model type: None
